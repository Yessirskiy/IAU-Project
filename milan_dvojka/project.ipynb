# %% [markdown]
# # Faza 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import shapiro, pearsonr, levene, ttest_ind
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## 1.1 A

# %% [markdown]
# Reading dataframe, separator is tab

# %%
conn_df = pd.read_csv("data\\connections.csv", sep="\t")
proc_df = pd.read_csv("data\\processes.csv", sep="\t")
devices_df = pd.read_csv("data\\devices.csv", sep="\t")
profiles_df = pd.read_csv("data\\profiles.csv", sep="\t")

# %% [markdown]
# ### Size each dataframe

# %%
print("Connections size (rows, columns):", conn_df.shape)
print("Processes size (rows, columns):", proc_df.shape)
print("Devices size (rows, columns):", devices_df.shape)
print("Profiles size (rows, columns):", profiles_df.shape)
# Out:
# Connections size (rows, columns): (15143, 13)
# Processes size (rows, columns): (15143, 23)
# Devices size (rows, columns): (2963, 6)
# Profiles size (rows, columns): (2537, 12)

# %% [markdown]
# ### Types of attributes

# %%
conn_df.dtypes
# Out:
# ts                    object
# imei                   int64
# mwra                 float64
# c.dogalize           float64
# c.android.chrome     float64
# c.katana             float64
# c.android.youtube    float64
# c.android.gm         float64
# c.updateassist       float64
# c.android.vending    float64
# c.UCMobile.intl      float64
# c.UCMobile.x86       float64
# c.raider             float64
# dtype: object

# %% [markdown]
# Types are imported correctly

# %%
proc_df.dtypes
# Out:
# ts                             object
# imei                            int64
# mwra                          float64
# p.android.packageinstaller    float64
# p.android.documentsui         float64
# p.android.chrome              float64
# p.android.settings            float64
# p.android.externalstorage     float64
# p.android.gm                  float64
# p.system                      float64
# p.browser.provider            float64
# p.notifier                    float64
# p.simulator                   float64
# p.gms.persistent              float64
# p.katana                      float64
# p.android.defcontainer        float64
# p.process.gapps               float64
# p.olauncher                   float64
# p.dogalize                    float64
# p.android.vending             float64
# p.google                      float64
# p.inputmethod.latin           float64
# p.android.gms                 float64
# dtype: object

# %% [markdown]
# Types are imported correctly

# %%
devices_df.dtypes
# Out:
# latitude      float64
# longitude     float64
# store_name     object
# code           object
# location       object
# imei            int64
# dtype: object

# %% [markdown]
# Types are imported correctly

# %%
profiles_df.dtypes
# Out:
# registration        object
# username            object
# residence           object
# company             object
# name                object
# birthdate           object
# ssn                 object
# mail                object
# user_id              int64
# current_location    object
# imei                 int64
# job                 object
# dtype: object

# %% [markdown]
# Types are imported correctly

# %% [markdown]
# There is no sign of mistype in any of these dataframes

# %%
print("Connections attributes:", *conn_df.columns)
print("Processes attributes:", *proc_df.columns)
print("Devices attributes:", *devices_df.columns)
print("Profiles attributes:", *profiles_df.columns)
# Out:
# Connections attributes: ts imei mwra c.dogalize c.android.chrome c.katana c.android.youtube c.android.gm c.updateassist c.android.vending c.UCMobile.intl c.UCMobile.x86 c.raider
# Processes attributes: ts imei mwra p.android.packageinstaller p.android.documentsui p.android.chrome p.android.settings p.android.externalstorage p.android.gm p.system p.browser.provider p.notifier p.simulator p.gms.persistent p.katana p.android.defcontainer p.process.gapps p.olauncher p.dogalize p.android.vending p.google p.inputmethod.latin p.android.gms
# Devices attributes: latitude longitude store_name code location imei
# Profiles attributes: registration username residence company name birthdate ssn mail user_id current_location imei job

# %% [markdown]
# We can notice, that all dataframes have *imei* attribute in it. IMEI stands for _International Mobile Equipment Identity_. So each row just represent particular data about single android device.

# %% [markdown]
# We can also notice, that connections and procecesses have the same naumber of rows and both have attribute called ts which stands for timestamp. It suggests that it might be logging of both connections and processes at the particular point in time:

# %%
(conn_df["ts"] == proc_df["ts"]).sum()
# Out:
# 15143

# %%
(conn_df["imei"] == proc_df["imei"]).sum()
# Out:
# 15143

# %%
(conn_df["mwra"] == proc_df["mwra"]).sum()
# Out:
# 15143

# %% [markdown]
# As we can see, the IMEI and TS are equal for each record in these two datasets which proves suggestion.

# %% [markdown]
# The devices dataframe may give an insight in the source of the devices (i.e. the place and time of purchase). The profiles dataframe may provide us an information of the users of the devices.

# %% [markdown]
# However, there is not much attributes to link connections or processes with devcies or profiles except IMEI field.

# %%
devices_df["imei"].unique().shape
# Out:
# (498,)

# %%
devices_df["imei"].shape
# Out:
# (2963,)

# %%
profiles_df["imei"].unique().shape
# Out:
# (495,)

# %%
profiles_df["imei"].shape
# Out:
# (2537,)

# %% [markdown]
# We can see that both profiles and devices have only around 500 unique IMEI records out of \~2500/\~3000 total records. So, most probably, these record just represent data related to particular phone.

# %% [markdown]
# ## 1.1B

# %% [markdown]
# Main numeric values are in processes and connections dataframes, so we will analyze attributes from these two dataframes.

# %% [markdown]
# Let's see distributions for all processes in processes_df:

# %%
proc_attributes =  proc_df.select_dtypes("float")
proc_attrs = proc_attributes.loc[:, proc_attributes.columns != 'mwra']
fig, axis = plt.subplots(4, 5, figsize=(20,15))
proc_attrs.hist(ax=axis, edgecolor='black', grid=False)
plt.show()

# %% [markdown]
# We can also get the list of normally distributed attributes using Shapiro-Wilk test:

# %%
proc_norm_list = []
proc_not_norm_list = []
for column in proc_attrs:
    if shapiro(proc_attrs[column]).pvalue > 0.05:
        proc_norm_list.append(column)
    else:
        proc_not_norm_list.append(column)
print("Normally distributed processes:", proc_norm_list)
# Out:
# Normally distributed processes: ['p.simulator', 'p.gms.persistent', 'p.katana', 'p.android.defcontainer']
# C:\Users\milan\AppData\Roaming\Python\Python312\site-packages\scipy\stats\_axis_nan_policy.py:573: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 15143.
#   res = hypotest_fun_out(*samples, **kwds)

# %% [markdown]
# Shapiro-Wilk revealed which attributes normally distributed and which attributes aren't:

# %%
proc_norm = proc_attrs[proc_norm_list]
proc_notnorm = proc_attrs[proc_not_norm_list]
proc_norm = pd.concat([proc_norm, proc_df["mwra"]], axis=1)
proc_norm
# Out:
#        p.simulator  p.gms.persistent  p.katana  p.android.defcontainer  mwra
# 0         35.71788          51.77164  40.23305                41.76549   1.0
# 1         29.55507          46.06186  66.35247                53.31959   0.0
# 2         32.34265          54.17242  46.94977                39.23991   0.0
# 3         63.09837          67.07612  49.81393                38.59364   0.0
# 4         42.41401          58.73573  50.35359                65.09269   1.0
# ...            ...               ...       ...                     ...   ...
# 15138     31.43787          68.53845  44.58185                43.78864   1.0
# 15139     42.81895          36.46882  39.13095                38.62800   0.0
# 15140     44.83145          65.44567  60.74023                33.61657   0.0
# 15141     47.39006          28.86566  49.14036                59.81838   0.0
# 15142     36.01724          56.88527  62.49117                39.22988   1.0
#
# [15143 rows x 5 columns]

# %% [markdown]
# Let's see the descriptive statistics for the attributes:

# %%
proc_attrs.describe()
# Out:
#        p.android.packageinstaller  p.android.documentsui  p.android.chrome  \
# count                15143.000000           15143.000000      15143.000000
# mean                     9.734081              11.530321         10.354774
# std                      2.353793               2.379354          2.560366
# min                      0.107530               2.332460          1.157840
# 25%                      8.108805              10.096745          8.508865
# 50%                      9.568570              11.921050         10.227180
# 75%                     11.209280              13.238575         12.194415
# max                     19.659630              18.067980         20.966080
#
#        p.android.settings  p.android.externalstorage  p.android.gm  \
# count        15143.000000               15143.000000  15143.000000
# mean            12.701517                  10.285296     10.386558
# std              2.043104                   2.789514      2.421371
# min              4.014640                   0.000000      2.147780
# 25%             11.406915                   8.352360      8.629830
# 50%             12.707480                  10.138900     10.030590
# 75%             14.029885                  12.103005     11.982615
# max             20.586340                  20.975710     19.808420
#
#            p.system  p.browser.provider    p.notifier   p.simulator  \
# count  15143.000000        15143.000000  15143.000000  15143.000000
# mean      10.892521           67.266917      0.180368     44.079895
# std        2.553577            7.803221      1.708792     13.527190
# min        3.127180            0.000000      0.000000      0.000000
# 25%        8.959910           62.003040      0.001250     34.903330
# 50%       10.715680           67.277050      0.008600     44.087750
# 75%       12.780965           72.435125      0.049075     53.216140
# max       21.229940          100.000000    100.000000    100.000000
#
#        p.gms.persistent      p.katana  p.android.defcontainer  \
# count      15143.000000  15143.000000            15143.000000
# mean          51.967771     50.942925               42.902683
# std           12.468146     12.141770               12.657218
# min            0.000000      0.000000                0.000000
# 25%           43.637225     42.925860               34.388385
# 50%           52.027850     50.908870               42.946220
# 75%           60.404405     59.073945               51.431855
# max          100.000000    100.000000              100.000000
#
#        p.process.gapps   p.olauncher    p.dogalize  p.android.vending  \
# count     15143.000000  15143.000000  15143.000000       15143.000000
# mean         49.438710     50.007092     49.688617          50.022847
# std          28.929395     28.845051     28.905844          28.934729
# min           0.000000      0.000000      0.000000           0.000000
# 25%          24.499375     24.976120     24.443920          24.924490
# 50%          49.204370     50.321980     49.587050          50.386190
# 75%          74.628445     74.997115     74.786680          74.904195
# max         100.000000    100.000000    100.000000         100.000000
#
#            p.google  p.inputmethod.latin  p.android.gms
# count  15143.000000         15143.000000   15143.000000
# mean      50.306934            50.250174      49.866868
# std       28.828845            28.813387      28.957585
# min        0.000000             0.000000       0.000000
# 25%       25.287315            25.572440      24.546590
# 50%       50.211930            50.450770      49.557470
# 75%       75.321355            75.259580      75.016335
# max      100.000000           100.000000     100.000000

# %% [markdown]
# Let's see distributions for all connections in conn_df:

# %%
conn_attributes =  conn_df.select_dtypes("float")
conn_attrs = conn_attributes.loc[:, conn_attributes.columns != 'mwra']
fig, axis = plt.subplots(2, 5, figsize=(20,6))
conn_attrs.hist(ax=axis, edgecolor='black', grid=False)
plt.show()

# %% [markdown]
# Histograms revealed that attributes before c.updateassist are normally distributed, while the others aren't:

# %%
conn_norm = conn_attrs.loc[:, :"c.android.gm"]
conn_notnorm = conn_attrs.loc[:, "c.updateassist":]
conn_norm = pd.concat([conn_norm, conn_df["mwra"]], axis=1)
conn_norm[conn_norm["mwra"] == 1]
# Out:
#        c.dogalize  c.android.chrome  c.katana  c.android.youtube  \
# 0        11.97002          15.25610  10.99463           12.94905
# 4         9.08043          14.14611   9.68923           13.12646
# 5        13.33874          15.94627  10.55827           12.33971
# 6        16.70785          14.63996  14.16997           15.02633
# 11        8.71281          11.20755  13.55143           11.79122
# ...           ...               ...       ...                ...
# 15132     9.86349          14.98360   9.80777            8.65737
# 15133    12.25497           8.32633  10.88130           12.51090
# 15134    12.69147           8.72604   8.95936           12.50919
# 15138    13.17188           9.06209   9.73345           13.07588
# 15142    14.51627          13.30292  13.09172           12.27001
#
#        c.android.gm  mwra
# 0           9.87441   1.0
# 4           8.82400   1.0
# 5          10.56274   1.0
# 6           2.90955   1.0
# 11         13.87891   1.0
# ...             ...   ...
# 15132       9.60043   1.0
# 15133       8.49994   1.0
# 15134      12.68571   1.0
# 15138      13.36728   1.0
# 15142       7.11088   1.0
#
# [9478 rows x 6 columns]

# %% [markdown]
# Let's see the descriptive statistics for the attributes:

# %%
conn_attrs.describe()
# Out:
#          c.dogalize  c.android.chrome      c.katana  c.android.youtube  \
# count  15143.000000      15143.000000  15143.000000       15143.000000
# mean      11.452411         10.900475     11.534564          12.061295
# std        2.661398          2.703876      2.785804           2.325038
# min        1.026250          0.291220      1.260930           2.053830
# 25%        9.571635          8.944125      9.717075          10.798585
# 50%       11.564450         10.834810     11.685900          12.323720
# 75%       13.314445         12.804725     13.526230          13.606590
# max       20.936100         21.131390     22.379300          20.731990
#
#        c.android.gm  c.updateassist  c.android.vending  c.UCMobile.intl  \
# count  15143.000000    15143.000000       15143.000000     15143.000000
# mean      10.253361       49.690945          49.875202        49.711246
# std        2.687359       28.980529          29.008906        28.682976
# min        1.482300        0.000000           0.000000         0.000000
# 25%        8.360420       24.689315          24.641910        25.329615
# 50%       10.064370       49.265910          49.907250        49.800630
# 75%       12.044015       74.881965          75.355220        74.043395
# max       20.710370      100.000000         100.000000       100.000000
#
#        c.UCMobile.x86      c.raider
# count    15143.000000  15143.000000
# mean        49.648245     49.770309
# std         29.062244     28.850271
# min          0.000000      0.000000
# 25%         24.236540     24.686350
# 50%         50.150860     49.457960
# 75%         74.871090     74.819100
# max        100.000000    100.000000

# %% [markdown]
# Let's concatenate connections and processes into a single dataframe:

# %%
numeric_attrs = pd.concat([proc_attrs, conn_attrs], axis=1)
numeric_attrs
# Out:
#        p.android.packageinstaller  p.android.documentsui  p.android.chrome  \
# 0                         8.91995               11.89842           8.46244
# 1                        10.68732               11.59558          11.76198
# 2                        12.18501               12.21622          14.41556
# 3                        11.99975               11.10215          14.74228
# 4                         9.37085               11.45016           6.69994
# ...                           ...                    ...               ...
# 15138                     7.84630                9.24068           7.71016
# 15139                     9.19186               10.95426           9.49733
# 15140                    10.27414               11.35433          14.47058
# 15141                     8.58038               14.50347          12.71542
# 15142                     9.73797               13.48996          10.98016
#
#        p.android.settings  p.android.externalstorage  p.android.gm  p.system  \
# 0                11.14348                   14.47905       8.41508  10.36537
# 1                12.51138                   10.27763      14.93886   8.64163
# 2                14.15739                   10.33481      10.68808   9.57202
# 3                13.20422                    6.66961      11.16616  11.70976
# 4                12.80673                   11.81094      10.15303   9.28381
# ...                   ...                        ...           ...       ...
# 15138            10.24473                   10.77534      10.00552  12.29869
# 15139            13.91152                    8.90165      11.81112  13.24911
# 15140            10.28513                   13.48562      15.08473  13.10745
# 15141            12.19887                    9.23179      11.25026  15.25759
# 15142            10.95912                   11.36365       7.99163  11.24343
#
#        p.browser.provider  p.notifier  p.simulator  ...  c.dogalize  \
# 0                65.46982     0.01284     35.71788  ...    11.97002
# 1                73.15339     0.00082     29.55507  ...     9.06416
# 2                68.51992     0.00378     32.34265  ...    10.71737
# 3                69.41012     0.00725     63.09837  ...    11.38573
# 4                57.32590     0.00087     42.41401  ...     9.08043
# ...                   ...         ...          ...  ...         ...
# 15138            65.77796     0.04257     31.43787  ...    13.17188
# 15139            70.88634     0.00023     42.81895  ...     7.28806
# 15140            68.88885     0.00018     44.83145  ...     7.35113
# 15141            69.60882     0.00430     47.39006  ...    10.86261
# 15142            79.61994     0.16301     36.01724  ...    14.51627
#
#        c.android.chrome  c.katana  c.android.youtube  c.android.gm  \
# 0              15.25610  10.99463           12.94905       9.87441
# 1               8.26843  12.37275           12.62434      11.03110
# 2              10.70129  11.52100           12.78995       8.83190
# 3              10.28395  14.22024           12.20206      10.84051
# 4              14.14611   9.68923           13.12646       8.82400
# ...                 ...       ...                ...           ...
# 15138           9.06209   9.73345           13.07588      13.36728
# 15139          10.61374   9.49010            9.77496       9.66189
# 15140          10.57486  18.32629           13.34462       9.25235
# 15141          16.25512  10.77980            5.68572      10.28164
# 15142          13.30292  13.09172           12.27001       7.11088
#
#        c.updateassist  c.android.vending  c.UCMobile.intl  c.UCMobile.x86  \
# 0            40.06991           39.05778         18.98343        71.44379
# 1            96.66128           29.37613          5.72059         1.58695
# 2            69.44777           78.92569         36.56047        19.09821
# 3            73.38944            1.86082         71.05049        30.04595
# 4            58.35019           76.91941         40.13552        39.93518
# ...               ...                ...              ...             ...
# 15138        33.90189           37.20471         85.92455        15.55486
# 15139        40.07666           30.93520         75.58962        88.90832
# 15140        93.91890           62.94537         11.73332        91.45692
# 15141        44.01314           39.58966         68.42259        73.99439
# 15142        19.96597           78.04930         38.07548        57.34194
#
#        c.raider
# 0      25.30727
# 1      93.97586
# 2      13.74044
# 3      17.95979
# 4      54.04827
# ...         ...
# 15138  36.12666
# 15139  17.03351
# 15140  38.21706
# 15141  79.98017
# 15142  88.21028
#
# [15143 rows x 30 columns]

# %% [markdown]
# Since connections and proccess share same ts, imei and mwra, let's add them too:

# %%
numeric_attrs = pd.concat([proc_df[["ts", "imei", "mwra"]], numeric_attrs], axis=1)
numeric_attrs
# Out:
#                         ts                 imei  mwra  \
# 0      2018-05-05 10:00:00  3590433799317662121   1.0
# 1      2018-05-05 10:01:00  3590433799317661875   0.0
# 2      2018-05-05 10:02:00  3590433799317662436   0.0
# 3      2018-05-05 10:03:00   359043379931766726   0.0
# 4      2018-05-05 10:04:00   359043379931766098   1.0
# ...                    ...                  ...   ...
# 15138  2018-05-08 11:33:00   359043379931766304   1.0
# 15139  2018-05-11 06:21:00  8630330696303481206   0.0
# 15140  2018-05-15 09:30:00   863033069630348222   0.0
# 15141  2018-05-10 23:44:00   863033069630348693   0.0
# 15142  2018-05-11 22:48:00  8630330696303481743   1.0
#
#        p.android.packageinstaller  p.android.documentsui  p.android.chrome  \
# 0                         8.91995               11.89842           8.46244
# 1                        10.68732               11.59558          11.76198
# 2                        12.18501               12.21622          14.41556
# 3                        11.99975               11.10215          14.74228
# 4                         9.37085               11.45016           6.69994
# ...                           ...                    ...               ...
# 15138                     7.84630                9.24068           7.71016
# 15139                     9.19186               10.95426           9.49733
# 15140                    10.27414               11.35433          14.47058
# 15141                     8.58038               14.50347          12.71542
# 15142                     9.73797               13.48996          10.98016
#
#        p.android.settings  p.android.externalstorage  p.android.gm  p.system  \
# 0                11.14348                   14.47905       8.41508  10.36537
# 1                12.51138                   10.27763      14.93886   8.64163
# 2                14.15739                   10.33481      10.68808   9.57202
# 3                13.20422                    6.66961      11.16616  11.70976
# 4                12.80673                   11.81094      10.15303   9.28381
# ...                   ...                        ...           ...       ...
# 15138            10.24473                   10.77534      10.00552  12.29869
# 15139            13.91152                    8.90165      11.81112  13.24911
# 15140            10.28513                   13.48562      15.08473  13.10745
# 15141            12.19887                    9.23179      11.25026  15.25759
# 15142            10.95912                   11.36365       7.99163  11.24343
#
#        ...  c.dogalize  c.android.chrome  c.katana  c.android.youtube  \
# 0      ...    11.97002          15.25610  10.99463           12.94905
# 1      ...     9.06416           8.26843  12.37275           12.62434
# 2      ...    10.71737          10.70129  11.52100           12.78995
# 3      ...    11.38573          10.28395  14.22024           12.20206
# 4      ...     9.08043          14.14611   9.68923           13.12646
# ...    ...         ...               ...       ...                ...
# 15138  ...    13.17188           9.06209   9.73345           13.07588
# 15139  ...     7.28806          10.61374   9.49010            9.77496
# 15140  ...     7.35113          10.57486  18.32629           13.34462
# 15141  ...    10.86261          16.25512  10.77980            5.68572
# 15142  ...    14.51627          13.30292  13.09172           12.27001
#
#        c.android.gm  c.updateassist  c.android.vending  c.UCMobile.intl  \
# 0           9.87441        40.06991           39.05778         18.98343
# 1          11.03110        96.66128           29.37613          5.72059
# 2           8.83190        69.44777           78.92569         36.56047
# 3          10.84051        73.38944            1.86082         71.05049
# 4           8.82400        58.35019           76.91941         40.13552
# ...             ...             ...                ...              ...
# 15138      13.36728        33.90189           37.20471         85.92455
# 15139       9.66189        40.07666           30.93520         75.58962
# 15140       9.25235        93.91890           62.94537         11.73332
# 15141      10.28164        44.01314           39.58966         68.42259
# 15142       7.11088        19.96597           78.04930         38.07548
#
#        c.UCMobile.x86  c.raider
# 0            71.44379  25.30727
# 1             1.58695  93.97586
# 2            19.09821  13.74044
# 3            30.04595  17.95979
# 4            39.93518  54.04827
# ...               ...       ...
# 15138        15.55486  36.12666
# 15139        88.90832  17.03351
# 15140        91.45692  38.21706
# 15141        73.99439  79.98017
# 15142        57.34194  88.21028
#
# [15143 rows x 33 columns]

# %% [markdown]
# Let's also concatenate both normally distributed attributes and not normally distributed parameters:

# %%
numeric_norm = pd.concat([proc_df[["ts", "imei", "mwra"]], proc_norm, conn_norm], axis=1)
numeric_notnorm = pd.concat([proc_df[["ts", "imei", "mwra"]], proc_notnorm, conn_notnorm], axis=1)

# %% [markdown]
# ## 1.1C & 1.1D

# %% [markdown]
# For those normally distributed attributes, Pearson's correlation will be applied to determine if there any link between attributes:

# %%
sns.heatmap(data=numeric_norm.select_dtypes("float").corr(method="pearson"))
plt.show()

# %% [markdown]
# For those not normally distributed, Spearman's correlation will be aplied:

# %%
sns.heatmap(data=numeric_notnorm.select_dtypes("float").corr(method="spearman"))
plt.show()

# %% [markdown]
# We can see no correlation has been found there between those not normally distributed.

# %% [markdown]
# ## 1.1E

# %% [markdown]
# There are couple of insights that heatmap may give us:
# 1) Chrome (browser) service \[perhaps\] often works with documents (documentsui), gmail services (gm), settings and package installer. And doesn't with external storage.
# 2) External storage \[perhaps\] often utilized by web connections (dogalize, chrome, katana, youtube)
# 3) Perhaps, dogalize connection doesn't let chrome and gmail proccess to operate normally. Meanwhile, it does work actively with notifications and \[perhaps\] launches youtube connections.

# %% [markdown]
# There are also correlations between target attribute and others:
# 1) Connections with youtube, dogalize and gmail may be potential source of malware activity.
# 2) Working with external storage may potentially be dangerous.
# 3) Probably, gmail service and chrome services run their own protections as it can explain strong negative correlation.

# %% [markdown]
# # 1.2

# %% [markdown]
# ## 1.2A

# %% [markdown]
# As it can be seen in both connections and processes dataframes data is comlete and has no issues (all the values are present and consistent, format is rigorious).

# %%
print(conn_df.isnull().sum().sum(), proc_df.isnull().sum().sum())
# Out:
# 0 0

# %% [markdown]
# So here we will mainly focus on devices and profiles dataframes:

# %% [markdown]
# #### Devices

# %%
devices_df.isnull().sum()
# Out:
# latitude      0
# longitude     0
# store_name    0
# code          3
# location      0
# imei          0
# dtype: int64

# %% [markdown]
# Let's find these three records which have empty values in codes

# %%
devices_df[devices_df["code"].isnull()]
# Out:
#       latitude  longitude store_name code         location  \
# 1591 -21.98333   16.91667  Okahandja  NaN  Africa/Windhoek
# 1598 -21.98333   16.91667  Okahandja  NaN  Africa/Windhoek
# 2408 -21.98333   16.91667  Okahandja  NaN  Africa/Windhoek
#
#                      imei
# 1591  3590433799317662493
# 1598   359043379931766783
# 2408   863033069630348370

# %% [markdown]
# As Windhoek is located in Republic of Namibia, let's use it's ISO-2 code to fill in the data:

# %%
devices_df.loc[devices_df["code"].isnull(), "code"] = "NA"
devices_df[devices_df["code"] == "NA"]
# Out:
#       latitude  longitude store_name code         location  \
# 1591 -21.98333   16.91667  Okahandja   NA  Africa/Windhoek
# 1598 -21.98333   16.91667  Okahandja   NA  Africa/Windhoek
# 2408 -21.98333   16.91667  Okahandja   NA  Africa/Windhoek
#
#                      imei
# 1591  3590433799317662493
# 1598   359043379931766783
# 2408   863033069630348370

# %% [markdown]
# Let's also check coordinates, since we know that the valid range of latitude in degrees is -90 and +90 for the southern and northern hemisphere, respectively. Longitude is in the range -180 and +180:

# %%
devices_df[(-180 <= devices_df["longitude"]) & (devices_df["longitude"] <= 180) & (-90 <= devices_df["latitude"]) & (devices_df["latitude"] <= 90)].shape
# Out:
# (2963, 6)

# %% [markdown]
# All coordinates are valid

# %%
devices_cleandf = devices_df

# %% [markdown]
# #### Profiles

# %% [markdown]
# Let's firstly estimate the number of empty values in each column:

# %%
profiles_df.isnull().sum()
# Out:
# registration           0
# username               0
# residence           1649
# company                0
# name                   0
# birthdate           1142
# ssn                    0
# mail                   0
# user_id                0
# current_location     127
# imei                   0
# job                 1776
# dtype: int64

# %%
profiles_df.shape
# Out:
# (2537, 12)

# %%
print("Residence empty (%):", 1649 / 2527 * 100)
print("birthdate empty (%):", 1142 / 2527 * 100)
print("current_location empty (%):", 127 / 2527 * 100)
print("job empty (%):", 1776 / 2527 * 100)
# Out:
# Residence empty (%): 65.25524337158686
# birthdate empty (%): 45.19192718638702
# current_location empty (%): 5.0257222002374355
# job empty (%): 70.2809655718243

# %% [markdown]
# It makes sense to drop residence and job columns as this value can be hardly substited and actually mostly are not presented in dataset.

# %%
profiles_cleandf = profiles_df.drop(["residence", "job"], axis=1)
profiles_cleandf
# Out:
#               registration       username                  company  \
# 0               2019/09/09    jasonmiller              Leonard Ltd
# 1              26 Oct 2022         bsmith   Lang, Garza and Martin
# 2               2023/11/12     jeanette92           Allison-Thomas
# 3               2022-03-01  mariagonzalez             Levine-Smith
# 4               2018/01/04        susan66                Gross Ltd
# ...                    ...            ...                      ...
# 2532            2018/12/21      randall20   Weaver, Logan and Chan
# 2533  10/16/2018, 00:00:00     downsdarin  Gill, Downs and Esparza
# 2534            2019-12-19   danieldeleon                Roth-Bell
# 2535  10/14/2021, 00:00:00       olivia11           Andrade-Rivera
# 2536            2021-08-02  vanessapowell   Mora, White and Stokes
#
#                     name   birthdate          ssn                       mail  \
# 0     Christopher Ramsey         NaN  456-43-0025    barbaraharper@yahoo.com
# 1           Matthew Ross         NaN  401-60-5272         lisakhan@yahoo.com
# 2           Bobby Garcia         NaN  756-46-0240          diana16@yahoo.com
# 3      Nicole Fitzgerald         NaN  110-17-7224  sullivananthony@gmail.com
# 4            Jeremy Ford  1925-08-22  209-60-6164      toddlewis@hotmail.com
# ...                  ...         ...          ...                        ...
# 2532     Andrew Mitchell         NaN  518-35-4627        brandonho@yahoo.com
# 2533      Michael Dodson  1965-01-15  382-24-1772       antoniomay@yahoo.com
# 2534      Jerry Peterson  1924-04-08  677-27-7010     simpsontracy@gmail.com
# 2535     Valerie Sanchez  2007-06-12  138-75-9242         gdavis@hotmail.com
# 2536       Meredith Khan         NaN  075-39-5520          heidi96@gmail.com
#
#       user_id                                  current_location  \
# 0         569  (Decimal('-35.4866605'), Decimal('-126.966117'))
# 1        1287   (Decimal('-71.2577755'), Decimal('-24.088612'))
# 2        1454     (Decimal('15.5502415'), Decimal('74.236302'))
# 3        2508      (Decimal('76.283353'), Decimal('-1.336879'))
# 4        1236     (Decimal('-1.2822215'), Decimal('25.470396'))
# ...       ...                                               ...
# 2532     1787                                               NaN
# 2533     1422     (Decimal('45.428582'), Decimal('-99.719827'))
# 2534     2429     (Decimal('-65.724331'), Decimal('71.251540'))
# 2535       19    (Decimal('37.6123115'), Decimal('104.117267'))
# 2536     1561     (Decimal('14.312591'), Decimal('176.360745'))
#
#                      imei
# 0     8630330696303482345
# 1      863033069630348305
# 2      863033069630348529
# 3     3590433799317661347
# 4      863033069630348057
# ...                   ...
# 2532  3590433799317662329
# 2533   359043379931766643
# 2534   863033069630348537
# 2535   359043379931766858
# 2536  3590433799317661487
#
# [2537 rows x 10 columns]

# %% [markdown]
# Further work regarding missing values will be done in 1.2B. Now let's see which columns have an inconsistent or inappropriate format:

# %%
profiles_cleandf.head()
# Out:
#   registration       username                 company                name  \
# 0   2019/09/09    jasonmiller             Leonard Ltd  Christopher Ramsey
# 1  26 Oct 2022         bsmith  Lang, Garza and Martin        Matthew Ross
# 2   2023/11/12     jeanette92          Allison-Thomas        Bobby Garcia
# 3   2022-03-01  mariagonzalez            Levine-Smith   Nicole Fitzgerald
# 4   2018/01/04        susan66               Gross Ltd         Jeremy Ford
#
#     birthdate          ssn                       mail  user_id  \
# 0         NaN  456-43-0025    barbaraharper@yahoo.com      569
# 1         NaN  401-60-5272         lisakhan@yahoo.com     1287
# 2         NaN  756-46-0240          diana16@yahoo.com     1454
# 3         NaN  110-17-7224  sullivananthony@gmail.com     2508
# 4  1925-08-22  209-60-6164      toddlewis@hotmail.com     1236
#
#                                    current_location                 imei
# 0  (Decimal('-35.4866605'), Decimal('-126.966117'))  8630330696303482345
# 1   (Decimal('-71.2577755'), Decimal('-24.088612'))   863033069630348305
# 2     (Decimal('15.5502415'), Decimal('74.236302'))   863033069630348529
# 3      (Decimal('76.283353'), Decimal('-1.336879'))  3590433799317661347
# 4     (Decimal('-1.2822215'), Decimal('25.470396'))   863033069630348057

# %% [markdown]
# It's obvious that registration has inconsistent format and current_location provides inconviniet format for futher processing. Let's firstly deal with registration.

# %%
from dateutil.parser import parse # To parse unknown datetime format
from datetime import datetime

# %%
parse(profiles_cleandf.iloc[0, 0], fuzzy=True)
# Out:
# datetime.datetime(2019, 9, 9, 0, 0)

# %% [markdown]
# That's how this util works, now let's create new column which will hold datetime values in a single unified format yyyy-dd-mm:

# %%
profiles_cleandf.insert(0, "regdate", profiles_cleandf["registration"].apply(parse, fuzzy=True))
profiles_cleandf.drop("registration", axis=1, inplace=True)
profiles_cleandf
# Out:
#         regdate       username                  company                name  \
# 0    2019-09-09    jasonmiller              Leonard Ltd  Christopher Ramsey
# 1    2022-10-26         bsmith   Lang, Garza and Martin        Matthew Ross
# 2    2023-11-12     jeanette92           Allison-Thomas        Bobby Garcia
# 3    2022-03-01  mariagonzalez             Levine-Smith   Nicole Fitzgerald
# 4    2018-01-04        susan66                Gross Ltd         Jeremy Ford
# ...         ...            ...                      ...                 ...
# 2532 2018-12-21      randall20   Weaver, Logan and Chan     Andrew Mitchell
# 2533 2018-10-16     downsdarin  Gill, Downs and Esparza      Michael Dodson
# 2534 2019-12-19   danieldeleon                Roth-Bell      Jerry Peterson
# 2535 2021-10-14       olivia11           Andrade-Rivera     Valerie Sanchez
# 2536 2021-08-02  vanessapowell   Mora, White and Stokes       Meredith Khan
#
#        birthdate          ssn                       mail  user_id  \
# 0            NaN  456-43-0025    barbaraharper@yahoo.com      569
# 1            NaN  401-60-5272         lisakhan@yahoo.com     1287
# 2            NaN  756-46-0240          diana16@yahoo.com     1454
# 3            NaN  110-17-7224  sullivananthony@gmail.com     2508
# 4     1925-08-22  209-60-6164      toddlewis@hotmail.com     1236
# ...          ...          ...                        ...      ...
# 2532         NaN  518-35-4627        brandonho@yahoo.com     1787
# 2533  1965-01-15  382-24-1772       antoniomay@yahoo.com     1422
# 2534  1924-04-08  677-27-7010     simpsontracy@gmail.com     2429
# 2535  2007-06-12  138-75-9242         gdavis@hotmail.com       19
# 2536         NaN  075-39-5520          heidi96@gmail.com     1561
#
#                                       current_location                 imei
# 0     (Decimal('-35.4866605'), Decimal('-126.966117'))  8630330696303482345
# 1      (Decimal('-71.2577755'), Decimal('-24.088612'))   863033069630348305
# 2        (Decimal('15.5502415'), Decimal('74.236302'))   863033069630348529
# 3         (Decimal('76.283353'), Decimal('-1.336879'))  3590433799317661347
# 4        (Decimal('-1.2822215'), Decimal('25.470396'))   863033069630348057
# ...                                                ...                  ...
# 2532                                               NaN  3590433799317662329
# 2533     (Decimal('45.428582'), Decimal('-99.719827'))   359043379931766643
# 2534     (Decimal('-65.724331'), Decimal('71.251540'))   863033069630348537
# 2535    (Decimal('37.6123115'), Decimal('104.117267'))   359043379931766858
# 2536     (Decimal('14.312591'), Decimal('176.360745'))  3590433799317661487
#
# [2537 rows x 10 columns]

# %% [markdown]
# It's also obvious  that current_location is in the unconvinient format too, let's parse it into two new columns: longitude and latitude:

# %%
import re
def get_latitude(value):
    if pd.isnull(value):
        return np.nan
    result = tuple(map(float, re.findall(r"-?\d*\.\d*", value)))
    if not result:
        return np.nan
    return result[0]
    
def get_longitude(value):
    if pd.isnull(value):
        return np.nan
    result = tuple(map(float, re.findall(r"-?\d*\.\d*", value)))
    if not result:
        return np.nan
    return result[1]

#profiles_cleandf["latitude"], profiles_cleandf["longitude"] = profiles_cleandf["current_location"].apply(get_coordinates)
#profiles_cleandf
profiles_cleandf["latitude"] = profiles_cleandf["current_location"].apply(get_latitude)
profiles_cleandf["longitude"] = profiles_cleandf["current_location"].apply(get_longitude)
profiles_cleandf.drop("current_location", axis=1, inplace=True)
profiles_cleandf
# Out:
#         regdate       username                  company                name  \
# 0    2019-09-09    jasonmiller              Leonard Ltd  Christopher Ramsey
# 1    2022-10-26         bsmith   Lang, Garza and Martin        Matthew Ross
# 2    2023-11-12     jeanette92           Allison-Thomas        Bobby Garcia
# 3    2022-03-01  mariagonzalez             Levine-Smith   Nicole Fitzgerald
# 4    2018-01-04        susan66                Gross Ltd         Jeremy Ford
# ...         ...            ...                      ...                 ...
# 2532 2018-12-21      randall20   Weaver, Logan and Chan     Andrew Mitchell
# 2533 2018-10-16     downsdarin  Gill, Downs and Esparza      Michael Dodson
# 2534 2019-12-19   danieldeleon                Roth-Bell      Jerry Peterson
# 2535 2021-10-14       olivia11           Andrade-Rivera     Valerie Sanchez
# 2536 2021-08-02  vanessapowell   Mora, White and Stokes       Meredith Khan
#
#        birthdate          ssn                       mail  user_id  \
# 0            NaN  456-43-0025    barbaraharper@yahoo.com      569
# 1            NaN  401-60-5272         lisakhan@yahoo.com     1287
# 2            NaN  756-46-0240          diana16@yahoo.com     1454
# 3            NaN  110-17-7224  sullivananthony@gmail.com     2508
# 4     1925-08-22  209-60-6164      toddlewis@hotmail.com     1236
# ...          ...          ...                        ...      ...
# 2532         NaN  518-35-4627        brandonho@yahoo.com     1787
# 2533  1965-01-15  382-24-1772       antoniomay@yahoo.com     1422
# 2534  1924-04-08  677-27-7010     simpsontracy@gmail.com     2429
# 2535  2007-06-12  138-75-9242         gdavis@hotmail.com       19
# 2536         NaN  075-39-5520          heidi96@gmail.com     1561
#
#                      imei   latitude   longitude
# 0     8630330696303482345 -35.486660 -126.966117
# 1      863033069630348305 -71.257775  -24.088612
# 2      863033069630348529  15.550242   74.236302
# 3     3590433799317661347  76.283353   -1.336879
# 4      863033069630348057  -1.282221   25.470396
# ...                   ...        ...         ...
# 2532  3590433799317662329        NaN         NaN
# 2533   359043379931766643  45.428582  -99.719827
# 2534   863033069630348537 -65.724331   71.251540
# 2535   359043379931766858  37.612311  104.117267
# 2536  3590433799317661487  14.312591  176.360745
#
# [2537 rows x 11 columns]

# %% [markdown]
# Let's check that we have the same 127 missing values and no more added

# %%
profiles_cleandf.isnull().sum()
# Out:
# regdate         0
# username        0
# company         0
# name            0
# birthdate    1142
# ssn             0
# mail            0
# user_id         0
# imei            0
# latitude      127
# longitude     127
# dtype: int64

# %% [markdown]
# ## 1.2B

# %% [markdown]
# Let's firstly resolve the missing latitude and longitdude. For every missing value let's use interpolation.

# %%
profiles_cleandf["latitude"] = profiles_cleandf["latitude"].interpolate(method='linear')
profiles_cleandf["longitude"] = profiles_cleandf["longitude"].interpolate(method='linear')
profiles_cleandf.isnull().sum()
# Out:
# regdate         0
# username        0
# company         0
# name            0
# birthdate    1142
# ssn             0
# mail            0
# user_id         0
# imei            0
# latitude        0
# longitude       0
# dtype: int64

# %% [markdown]
# For each birthdate that we have let's calculate the age (the age at the time of registration (regdate))

# %%
def get_age(value, reg_date):
    if pd.isnull(value):
        return np.nan
    d1 = parse(value, fuzzy=True)
    return (reg_date - d1).days // 365

profiles_cleandf["age"] = profiles_cleandf.apply(lambda row: get_age(row["birthdate"], row["regdate"]), axis=1)
profiles_cleandf["age"].describe()
# Out:
# count    1395.000000
# mean       53.901075
# std        34.080990
# min        -6.000000
# 25%        25.000000
# 50%        52.000000
# 75%        82.000000
# max       115.000000
# Name: age, dtype: float64

# %% [markdown]
# Some of the obtained number make no sense, or very unlikely to be happening.

# %%
(profiles_cleandf["age"] < 0).sum()
# Out:
# 45

# %%
(profiles_cleandf["age"] > 100).sum()
# Out:
# 163

# %% [markdown]
# Slightly more than 200 records are invalid, even if we eliminate these values we get:

# %%
(1142 + 45 + 163) / 2527 * 100, "% of missing ages"
# Out:
# (53.423031262366436, '% of missing ages')

# %% [markdown]
# As it will significantly affect future analysis, the birthdate and age columns must be removed:

# %%
profiles_cleandf.drop(["age", "birthdate"], axis=1, inplace=True)
profiles_cleandf
# Out:
#         regdate       username                  company                name  \
# 0    2019-09-09    jasonmiller              Leonard Ltd  Christopher Ramsey
# 1    2022-10-26         bsmith   Lang, Garza and Martin        Matthew Ross
# 2    2023-11-12     jeanette92           Allison-Thomas        Bobby Garcia
# 3    2022-03-01  mariagonzalez             Levine-Smith   Nicole Fitzgerald
# 4    2018-01-04        susan66                Gross Ltd         Jeremy Ford
# ...         ...            ...                      ...                 ...
# 2532 2018-12-21      randall20   Weaver, Logan and Chan     Andrew Mitchell
# 2533 2018-10-16     downsdarin  Gill, Downs and Esparza      Michael Dodson
# 2534 2019-12-19   danieldeleon                Roth-Bell      Jerry Peterson
# 2535 2021-10-14       olivia11           Andrade-Rivera     Valerie Sanchez
# 2536 2021-08-02  vanessapowell   Mora, White and Stokes       Meredith Khan
#
#               ssn                       mail  user_id                 imei  \
# 0     456-43-0025    barbaraharper@yahoo.com      569  8630330696303482345
# 1     401-60-5272         lisakhan@yahoo.com     1287   863033069630348305
# 2     756-46-0240          diana16@yahoo.com     1454   863033069630348529
# 3     110-17-7224  sullivananthony@gmail.com     2508  3590433799317661347
# 4     209-60-6164      toddlewis@hotmail.com     1236   863033069630348057
# ...           ...                        ...      ...                  ...
# 2532  518-35-4627        brandonho@yahoo.com     1787  3590433799317662329
# 2533  382-24-1772       antoniomay@yahoo.com     1422   359043379931766643
# 2534  677-27-7010     simpsontracy@gmail.com     2429   863033069630348537
# 2535  138-75-9242         gdavis@hotmail.com       19   359043379931766858
# 2536  075-39-5520          heidi96@gmail.com     1561  3590433799317661487
#
#        latitude   longitude
# 0    -35.486660 -126.966117
# 1    -71.257775  -24.088612
# 2     15.550242   74.236302
# 3     76.283353   -1.336879
# 4     -1.282221   25.470396
# ...         ...         ...
# 2532  64.801457  -34.679736
# 2533  45.428582  -99.719827
# 2534 -65.724331   71.251540
# 2535  37.612311  104.117267
# 2536  14.312591  176.360745
#
# [2537 rows x 10 columns]

# %% [markdown]
# ## 1.2C

# %% [markdown]
# Let's use boxplots to see an outliers in the datasets. Firstly, proccesses outliers will be visualized:

# %%
sns.set_theme(rc={'figure.figsize':(16,8)})
sns.boxplot(data=proc_attrs)
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# Let's iterate through the processes and substituted values that are below lower bound (-1,5 * iqr) substite with global min value of the attribute. Symmetric method will be applied to those values above upper bound:

# %%
def iqr_sub(value, lb, ub):
    if value < lb:
        return lb
    elif value > ub:
        return ub
    return value

proc_cleandf = pd.DataFrame()
for column in proc_attrs:
    lq = proc_attrs[column].quantile(0.25)
    uq = proc_attrs[column].quantile(0.75)
    iqr = uq - lq
    lb = lq - 1.5 * iqr
    ub = uq + 1.5 * iqr
    proc_cleandf[column] = proc_attrs[column].apply(iqr_sub, lb=lb, ub=ub)
proc_cleandf["mwra"] = proc_df["mwra"]
#proc_cleandf["imei"] = proc_df["imei"]
proc_cleandf
# Out:
#        p.android.packageinstaller  p.android.documentsui  p.android.chrome  \
# 0                         8.91995               11.89842           8.46244
# 1                        10.68732               11.59558          11.76198
# 2                        12.18501               12.21622          14.41556
# 3                        11.99975               11.10215          14.74228
# 4                         9.37085               11.45016           6.69994
# ...                           ...                    ...               ...
# 15138                     7.84630                9.24068           7.71016
# 15139                     9.19186               10.95426           9.49733
# 15140                    10.27414               11.35433          14.47058
# 15141                     8.58038               14.50347          12.71542
# 15142                     9.73797               13.48996          10.98016
#
#        p.android.settings  p.android.externalstorage  p.android.gm  p.system  \
# 0                11.14348                   14.47905       8.41508  10.36537
# 1                12.51138                   10.27763      14.93886   8.64163
# 2                14.15739                   10.33481      10.68808   9.57202
# 3                13.20422                    6.66961      11.16616  11.70976
# 4                12.80673                   11.81094      10.15303   9.28381
# ...                   ...                        ...           ...       ...
# 15138            10.24473                   10.77534      10.00552  12.29869
# 15139            13.91152                    8.90165      11.81112  13.24911
# 15140            10.28513                   13.48562      15.08473  13.10745
# 15141            12.19887                    9.23179      11.25026  15.25759
# 15142            10.95912                   11.36365       7.99163  11.24343
#
#        p.browser.provider  p.notifier  p.simulator  ...  p.katana  \
# 0                65.46982    0.012840     35.71788  ...  40.23305
# 1                73.15339    0.000820     29.55507  ...  66.35247
# 2                68.51992    0.003780     32.34265  ...  46.94977
# 3                69.41012    0.007250     63.09837  ...  49.81393
# 4                57.32590    0.000870     42.41401  ...  50.35359
# ...                   ...         ...          ...  ...       ...
# 15138            65.77796    0.042570     31.43787  ...  44.58185
# 15139            70.88634    0.000230     42.81895  ...  39.13095
# 15140            68.88885    0.000180     44.83145  ...  60.74023
# 15141            69.60882    0.004300     47.39006  ...  49.14036
# 15142            79.61994    0.120812     36.01724  ...  62.49117
#
#        p.android.defcontainer  p.process.gapps  p.olauncher  p.dogalize  \
# 0                    41.76549         77.40536     26.71819    11.19222
# 1                    53.31959         85.89408     65.69709    20.79102
# 2                    39.23991          7.70864     47.92101    34.24409
# 3                    38.59364         38.29756     64.82239     4.02760
# 4                    65.09269         39.94857     95.61363    18.83120
# ...                       ...              ...          ...         ...
# 15138                43.78864         31.16809      3.58429    51.84587
# 15139                38.62800          5.79894     98.54661    90.55095
# 15140                33.61657         59.01505     45.48557    45.60939
# 15141                59.81838         58.51410     21.56260    79.89379
# 15142                39.22988         80.75805     35.92453    57.13355
#
#        p.android.vending  p.google  p.inputmethod.latin  p.android.gms  mwra
# 0               83.50266  82.38566             78.12107       87.46864   1.0
# 1               41.56210  67.61604              4.45278       70.51106   0.0
# 2               64.01791  20.22138             55.47605       59.70921   0.0
# 3                8.27247   1.84871             40.46046        4.23065   0.0
# 4               48.18806  78.73258             72.00605       89.88852   1.0
# ...                  ...       ...                  ...            ...   ...
# 15138           93.38507  97.79335             41.18310       83.78633   1.0
# 15139           54.28171  88.67928             12.58515       64.13703   0.0
# 15140           69.47574  71.68410              3.79638       72.27465   0.0
# 15141           94.82321  54.40711             84.59678       16.18317   0.0
# 15142           45.52966  91.81022             57.21457       93.24578   1.0
#
# [15143 rows x 21 columns]

# %% [markdown]
# Let's verify:

# %%
sns.set_theme(rc={'figure.figsize':(16,8)})
sns.boxplot(data=proc_cleandf)
plt.xticks(rotation=30)
plt.show()

# %%
sns.set_theme(rc={'figure.figsize':(16,8)})
sns.boxplot(data=conn_attrs)
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# Let's remove the values that are not in range of [lb; ub]:

# %%
conn_cleandf = pd.DataFrame()
for column in conn_attrs:
    lq = conn_attrs[column].quantile(0.25)
    uq = conn_attrs[column].quantile(0.75)
    iqr = uq - lq
    lb = lq - 1.5 * iqr
    ub = uq + 1.5 * iqr
    conn_cleandf[column] = conn_attrs[column].apply(iqr_sub, lb=lb, ub=ub)
conn_cleandf["mwra"] = proc_df["mwra"]
#proc_cleandf["imei"] = proc_df["imei"]
conn_cleandf
# Out:
#        c.dogalize  c.android.chrome  c.katana  c.android.youtube  \
# 0        11.97002          15.25610  10.99463          12.949050
# 1         9.06416           8.26843  12.37275          12.624340
# 2        10.71737          10.70129  11.52100          12.789950
# 3        11.38573          10.28395  14.22024          12.202060
# 4         9.08043          14.14611   9.68923          13.126460
# ...           ...               ...       ...                ...
# 15138    13.17188           9.06209   9.73345          13.075880
# 15139     7.28806          10.61374   9.49010           9.774960
# 15140     7.35113          10.57486  18.32629          13.344620
# 15141    10.86261          16.25512  10.77980           6.586577
# 15142    14.51627          13.30292  13.09172          12.270010
#
#        c.android.gm  c.updateassist  c.android.vending  c.UCMobile.intl  \
# 0           9.87441        40.06991           39.05778         18.98343
# 1          11.03110        96.66128           29.37613          5.72059
# 2           8.83190        69.44777           78.92569         36.56047
# 3          10.84051        73.38944            1.86082         71.05049
# 4           8.82400        58.35019           76.91941         40.13552
# ...             ...             ...                ...              ...
# 15138      13.36728        33.90189           37.20471         85.92455
# 15139       9.66189        40.07666           30.93520         75.58962
# 15140       9.25235        93.91890           62.94537         11.73332
# 15141      10.28164        44.01314           39.58966         68.42259
# 15142       7.11088        19.96597           78.04930         38.07548
#
#        c.UCMobile.x86  c.raider  mwra
# 0            71.44379  25.30727   1.0
# 1             1.58695  93.97586   0.0
# 2            19.09821  13.74044   0.0
# 3            30.04595  17.95979   0.0
# 4            39.93518  54.04827   1.0
# ...               ...       ...   ...
# 15138        15.55486  36.12666   1.0
# 15139        88.90832  17.03351   0.0
# 15140        91.45692  38.21706   0.0
# 15141        73.99439  79.98017   0.0
# 15142        57.34194  88.21028   1.0
#
# [15143 rows x 11 columns]

# %% [markdown]
# Let's verify:

# %%
sns.set_theme(rc={'figure.figsize':(16,8)})
sns.boxplot(data=conn_cleandf)
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# Profiles and devices do not contain any numerical data that might be used in outliers analysis (i.e. there are no outliers in coordinates)

# %%
# DataFrames to work with:
# proc_cleandf and conn_cleandf - processes and connections with not outliers or empty values
# profiles_cleandf and devices_cleandf - profiles and devices with no empty values (devices_cleandf is literally link to devices_df)

# %%
proc_cleandf
# Out:
#        p.android.packageinstaller  p.android.documentsui  p.android.chrome  \
# 0                         8.91995               11.89842           8.46244
# 1                        10.68732               11.59558          11.76198
# 2                        12.18501               12.21622          14.41556
# 3                        11.99975               11.10215          14.74228
# 4                         9.37085               11.45016           6.69994
# ...                           ...                    ...               ...
# 15138                     7.84630                9.24068           7.71016
# 15139                     9.19186               10.95426           9.49733
# 15140                    10.27414               11.35433          14.47058
# 15141                     8.58038               14.50347          12.71542
# 15142                     9.73797               13.48996          10.98016
#
#        p.android.settings  p.android.externalstorage  p.android.gm  p.system  \
# 0                11.14348                   14.47905       8.41508  10.36537
# 1                12.51138                   10.27763      14.93886   8.64163
# 2                14.15739                   10.33481      10.68808   9.57202
# 3                13.20422                    6.66961      11.16616  11.70976
# 4                12.80673                   11.81094      10.15303   9.28381
# ...                   ...                        ...           ...       ...
# 15138            10.24473                   10.77534      10.00552  12.29869
# 15139            13.91152                    8.90165      11.81112  13.24911
# 15140            10.28513                   13.48562      15.08473  13.10745
# 15141            12.19887                    9.23179      11.25026  15.25759
# 15142            10.95912                   11.36365       7.99163  11.24343
#
#        p.browser.provider  p.notifier  p.simulator  ...  p.katana  \
# 0                65.46982    0.012840     35.71788  ...  40.23305
# 1                73.15339    0.000820     29.55507  ...  66.35247
# 2                68.51992    0.003780     32.34265  ...  46.94977
# 3                69.41012    0.007250     63.09837  ...  49.81393
# 4                57.32590    0.000870     42.41401  ...  50.35359
# ...                   ...         ...          ...  ...       ...
# 15138            65.77796    0.042570     31.43787  ...  44.58185
# 15139            70.88634    0.000230     42.81895  ...  39.13095
# 15140            68.88885    0.000180     44.83145  ...  60.74023
# 15141            69.60882    0.004300     47.39006  ...  49.14036
# 15142            79.61994    0.120812     36.01724  ...  62.49117
#
#        p.android.defcontainer  p.process.gapps  p.olauncher  p.dogalize  \
# 0                    41.76549         77.40536     26.71819    11.19222
# 1                    53.31959         85.89408     65.69709    20.79102
# 2                    39.23991          7.70864     47.92101    34.24409
# 3                    38.59364         38.29756     64.82239     4.02760
# 4                    65.09269         39.94857     95.61363    18.83120
# ...                       ...              ...          ...         ...
# 15138                43.78864         31.16809      3.58429    51.84587
# 15139                38.62800          5.79894     98.54661    90.55095
# 15140                33.61657         59.01505     45.48557    45.60939
# 15141                59.81838         58.51410     21.56260    79.89379
# 15142                39.22988         80.75805     35.92453    57.13355
#
#        p.android.vending  p.google  p.inputmethod.latin  p.android.gms  mwra
# 0               83.50266  82.38566             78.12107       87.46864   1.0
# 1               41.56210  67.61604              4.45278       70.51106   0.0
# 2               64.01791  20.22138             55.47605       59.70921   0.0
# 3                8.27247   1.84871             40.46046        4.23065   0.0
# 4               48.18806  78.73258             72.00605       89.88852   1.0
# ...                  ...       ...                  ...            ...   ...
# 15138           93.38507  97.79335             41.18310       83.78633   1.0
# 15139           54.28171  88.67928             12.58515       64.13703   0.0
# 15140           69.47574  71.68410              3.79638       72.27465   0.0
# 15141           94.82321  54.40711             84.59678       16.18317   0.0
# 15142           45.52966  91.81022             57.21457       93.24578   1.0
#
# [15143 rows x 21 columns]

# %% [markdown]
# ## 1.2C

# %% [markdown]
# ### Hypothesis 1

# %% [markdown]
# **H0** c.android.youtube má v priemere vyššiu váhu v stave malware-related-activity ako v normálnom stave

# %% [markdown]
# **H1** c.android.yotube nemá v priemere vyššiu váhu v stave malware-related-activity ako v normálnom stave

# %%
youtube_mwra_high = conn_cleandf[conn_cleandf["mwra"] == 1]["c.android.youtube"]
youtube_mwra_low = conn_cleandf[conn_cleandf["mwra"] == 0]["c.android.youtube"]
ttest_ind(youtube_mwra_high, youtube_mwra_low)
# Out:
# TtestResult(statistic=38.365504072598505, pvalue=2.0572822993707507e-307, df=15141.0)

# %% [markdown]
# $pvalue < 0.05$, therefore we must reject the null hypothesis: c.android.youtube nemá v priemere vyššiu váhu v stave malware-related-activity ako v normálnom stave

# %% [markdown]
# ## Hypothesis 2

# %% [markdown]
# **H0** c.katana má v priemere vyššiu váhu v stave malware-related-activity ako v normálnom stave

# %% [markdown]
# **H1** c.katana nemá v priemere vyššiu váhu v stave malware-related-activity ako v normálnom stave

# %%
katana_mwra_high = conn_cleandf[conn_cleandf["mwra"] == 1]["c.katana"]
katana_mwra_low = conn_cleandf[conn_cleandf["mwra"] == 0]["c.katana"]
ttest_ind(katana_mwra_high, katana_mwra_low)
# Out:
# TtestResult(statistic=-35.0221351951738, pvalue=1.8656570807800096e-258, df=15141.0)

# %% [markdown]
# $pvalue < 0.05$, therefore we must reject the null hypothesis: c.katana nemá v priemere vyššiu váhu v stave malware-related-activity ako v normálnom stave

# %% [markdown]
# # Faza 2

# %% [markdown]
# ## 2.1

# %% [markdown]
# ### A

# %% [markdown]
# Firstly, let's merge cleaned datafrarames of connections and processes:

# %%
X = pd.concat([proc_cleandf.loc[:, :"p.android.gms"], conn_cleandf], axis=1)
y = X.pop('mwra')
X
# Out:
#        p.android.packageinstaller  p.android.documentsui  p.android.chrome  \
# 0                         8.91995               11.89842           8.46244
# 1                        10.68732               11.59558          11.76198
# 2                        12.18501               12.21622          14.41556
# 3                        11.99975               11.10215          14.74228
# 4                         9.37085               11.45016           6.69994
# ...                           ...                    ...               ...
# 15138                     7.84630                9.24068           7.71016
# 15139                     9.19186               10.95426           9.49733
# 15140                    10.27414               11.35433          14.47058
# 15141                     8.58038               14.50347          12.71542
# 15142                     9.73797               13.48996          10.98016
#
#        p.android.settings  p.android.externalstorage  p.android.gm  p.system  \
# 0                11.14348                   14.47905       8.41508  10.36537
# 1                12.51138                   10.27763      14.93886   8.64163
# 2                14.15739                   10.33481      10.68808   9.57202
# 3                13.20422                    6.66961      11.16616  11.70976
# 4                12.80673                   11.81094      10.15303   9.28381
# ...                   ...                        ...           ...       ...
# 15138            10.24473                   10.77534      10.00552  12.29869
# 15139            13.91152                    8.90165      11.81112  13.24911
# 15140            10.28513                   13.48562      15.08473  13.10745
# 15141            12.19887                    9.23179      11.25026  15.25759
# 15142            10.95912                   11.36365       7.99163  11.24343
#
#        p.browser.provider  p.notifier  p.simulator  ...  c.dogalize  \
# 0                65.46982    0.012840     35.71788  ...    11.97002
# 1                73.15339    0.000820     29.55507  ...     9.06416
# 2                68.51992    0.003780     32.34265  ...    10.71737
# 3                69.41012    0.007250     63.09837  ...    11.38573
# 4                57.32590    0.000870     42.41401  ...     9.08043
# ...                   ...         ...          ...  ...         ...
# 15138            65.77796    0.042570     31.43787  ...    13.17188
# 15139            70.88634    0.000230     42.81895  ...     7.28806
# 15140            68.88885    0.000180     44.83145  ...     7.35113
# 15141            69.60882    0.004300     47.39006  ...    10.86261
# 15142            79.61994    0.120812     36.01724  ...    14.51627
#
#        c.android.chrome  c.katana  c.android.youtube  c.android.gm  \
# 0              15.25610  10.99463          12.949050       9.87441
# 1               8.26843  12.37275          12.624340      11.03110
# 2              10.70129  11.52100          12.789950       8.83190
# 3              10.28395  14.22024          12.202060      10.84051
# 4              14.14611   9.68923          13.126460       8.82400
# ...                 ...       ...                ...           ...
# 15138           9.06209   9.73345          13.075880      13.36728
# 15139          10.61374   9.49010           9.774960       9.66189
# 15140          10.57486  18.32629          13.344620       9.25235
# 15141          16.25512  10.77980           6.586577      10.28164
# 15142          13.30292  13.09172          12.270010       7.11088
#
#        c.updateassist  c.android.vending  c.UCMobile.intl  c.UCMobile.x86  \
# 0            40.06991           39.05778         18.98343        71.44379
# 1            96.66128           29.37613          5.72059         1.58695
# 2            69.44777           78.92569         36.56047        19.09821
# 3            73.38944            1.86082         71.05049        30.04595
# 4            58.35019           76.91941         40.13552        39.93518
# ...               ...                ...              ...             ...
# 15138        33.90189           37.20471         85.92455        15.55486
# 15139        40.07666           30.93520         75.58962        88.90832
# 15140        93.91890           62.94537         11.73332        91.45692
# 15141        44.01314           39.58966         68.42259        73.99439
# 15142        19.96597           78.04930         38.07548        57.34194
#
#        c.raider
# 0      25.30727
# 1      93.97586
# 2      13.74044
# 3      17.95979
# 4      54.04827
# ...         ...
# 15138  36.12666
# 15139  17.03351
# 15140  38.21706
# 15141  79.98017
# 15142  88.21028
#
# [15143 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=23)
X_train
# Out:
#        p.android.packageinstaller  p.android.documentsui  p.android.chrome  \
# 3350                     10.68308                6.77499           9.68340
# 10268                    10.41977               11.00901          10.17736
# 12231                    11.35077               11.39427           9.15616
# 12431                    10.30322               12.59244          11.01613
# 2845                      6.46594               11.70739           8.32911
# ...                           ...                    ...               ...
# 11190                     7.51777               13.75522          10.76006
# 10185                     9.44603               11.91940           5.86259
# 9256                      8.87911               12.37779          14.50232
# 13030                     9.48372                7.66630          10.92072
# 8787                     13.22109               10.86921          10.01837
#
#        p.android.settings  p.android.externalstorage  p.android.gm  p.system  \
# 3350             13.92090                    6.46540       8.39208  16.20986
# 10268            12.63925                    9.74738      11.39775  12.04450
# 12231            13.17801                    6.88643      13.30899  12.37527
# 12431            10.73463                   12.03459      12.66582  13.68015
# 2845             11.35678                    7.27019       9.08770  11.90155
# ...                   ...                        ...           ...       ...
# 11190             9.62702                    7.42718      12.78345  13.12812
# 10185             9.64513                   15.94706       8.75262   8.08410
# 9256             13.34901                    8.83956      16.46388  11.49698
# 13030            11.74230                    7.85785       8.15376  13.92504
# 8787             11.78045                   11.50199      13.42039  10.17768
#
#        p.browser.provider  p.notifier  p.simulator  ...  c.dogalize  \
# 3350             81.52979    0.007870     19.30261  ...    11.47716
# 10268            74.43115    0.006700     38.07628  ...    11.31164
# 12231            63.21130    0.000120     22.56669  ...     6.52561
# 12431            66.49959    0.000840     42.33087  ...     9.10664
# 2845             66.88280    0.120812     44.76724  ...    14.52956
# ...                   ...         ...          ...  ...         ...
# 11190            51.95978    0.000660     54.66405  ...     8.88033
# 10185            72.68559    0.021220     58.38293  ...    12.47174
# 9256             57.83507    0.000220     44.94866  ...     7.41880
# 13030            60.10277    0.000140     23.37918  ...     6.77101
# 8787             66.95574    0.000700     55.52618  ...     8.92649
#
#        c.android.chrome  c.katana  c.android.youtube  c.android.gm  \
# 3350           10.89040  11.40553           11.86891      12.42740
# 10268           7.81465  12.42482           13.11656      12.27430
# 12231           9.61538   9.51809            7.71411       8.15663
# 12431          11.85506  15.38492            8.48019       8.42181
# 2845            8.15037   8.25232           14.65701       9.27386
# ...                 ...       ...                ...           ...
# 11190          12.69254  10.96752            7.56393      10.43851
# 10185          15.09224   8.06439           14.60234       8.65543
# 9256           12.98034  11.36388            8.35462      10.11711
# 13030          12.46089  11.08459            9.06256      14.66499
# 8787            7.88566  13.89869           13.32859       7.65818
#
#        c.updateassist  c.android.vending  c.UCMobile.intl  c.UCMobile.x86  \
# 3350         14.80962           97.90070         10.26879        12.40957
# 10268        42.00764           20.39326         13.40161        60.27877
# 12231        26.27054           44.47061         80.93344         2.75711
# 12431        97.42976           24.83930         15.13932         1.34660
# 2845         24.99987           64.84961         31.27997        26.63457
# ...               ...                ...              ...             ...
# 11190        96.78455           43.41658         61.65651        74.98842
# 10185        21.46851           50.01061         98.83985        28.68508
# 9256         95.52523           24.99265         40.16772        21.82220
# 13030        71.71174           55.66396         81.59201        31.59809
# 8787         34.57868           16.43090          1.80034        17.97700
#
#        c.raider
# 3350   12.71754
# 10268  70.05353
# 12231  34.34754
# 12431  34.67225
# 2845   99.04423
# ...         ...
# 11190  91.72815
# 10185  19.30675
# 9256   24.09095
# 13030  85.16478
# 8787   89.84917
#
# [10145 rows x 30 columns]

# %% [markdown]
# ### B

# %% [markdown]
# Let's make sure there are no missing values:

# %%
X_train.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Let's see if all the values are numeric:

# %%
X_train.select_dtypes("number").shape[1] == X_train.shape[1]
# Out:
# True

# %% [markdown]
# ### C

# %% [markdown]
# Let's apply scaling and transforming to the data. To test different techniques, we will firstly try the combination of square root transformation + min-max scaler. Then, we will try the combination of quantile transformation + standardization.

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import StandardScaler 
import numpy as np

# %% [markdown]
# Combination 1: square root transformation + min-max scaling. Square Root can be applied since we don't have negative values in our dataset.

# %%
 (X_train < 0).any().any() # Checking for negative values in the dataset
# Out:
# False

# %%
X_train_squared = X_train.apply(np.sqrt)
X_train_squared
# Out:
#        p.android.packageinstaller  p.android.documentsui  p.android.chrome  \
# 3350                     3.268498               2.602881          3.111816
# 10268                    3.227967               3.317983          3.190197
# 12231                    3.369090               3.375540          3.025915
# 12431                    3.209863               3.548583          3.319056
# 2845                     2.542821               3.421606          2.886020
# ...                           ...                    ...               ...
# 11190                    2.741855               3.708803          3.280253
# 10185                    3.073439               3.452448          2.421279
# 9256                     2.979784               3.518208          3.808191
# 13030                    3.079565               2.768808          3.304651
# 8787                     3.636082               3.296848          3.165181
#
#        p.android.settings  p.android.externalstorage  p.android.gm  p.system  \
# 3350             3.731072                   2.542715      2.896909  4.026147
# 10268            3.555172                   3.122079      3.376055  3.470519
# 12231            3.630153                   2.624201      3.648149  3.517850
# 12431            3.276375                   3.469091      3.558907  3.698669
# 2845             3.369982                   2.696329      3.014581  3.449862
# ...                   ...                        ...           ...       ...
# 11190            3.102744                   2.725285      3.575395  3.623275
# 10185            3.105661                   3.993377      2.958483  2.843255
# 9256             3.653630                   2.973140      4.057571  3.390720
# 13030            3.426704                   2.803186      2.855479  3.731627
# 8787             3.432266                   3.391458      3.663385  3.190248
#
#        p.browser.provider  p.notifier  p.simulator  ...  c.dogalize  \
# 3350             9.029385    0.088713     4.393474  ...    3.387796
# 10268            8.627349    0.081854     6.170598  ...    3.363278
# 12231            7.950553    0.010954     4.750441  ...    2.554527
# 12431            8.154728    0.028983     6.506218  ...    3.017721
# 2845             8.178191    0.347581     6.690833  ...    3.811766
# ...                   ...         ...          ...  ...         ...
# 11190            7.208313    0.025690     7.393514  ...    2.979988
# 10185            8.525584    0.145671     7.640872  ...    3.531535
# 9256             7.604937    0.014832     6.704376  ...    2.723747
# 13030            7.752598    0.011832     4.835202  ...    2.602116
# 8787             8.182649    0.026458     7.451589  ...    2.987723
#
#        c.android.chrome  c.katana  c.android.youtube  c.android.gm  \
# 3350           3.300061  3.377207           3.445128      3.525252
# 10268          2.795470  3.524886           3.621679      3.503470
# 12231          3.100868  3.085140           2.777429      2.855981
# 12431          3.443118  3.922362           2.912077      2.902035
# 2845           2.854885  2.872685           3.828447      3.045301
# ...                 ...       ...                ...           ...
# 11190          3.562659  3.311725           2.750260      3.230868
# 10185          3.884873  2.839787           3.821301      2.942011
# 9256           3.602824  3.371035           2.890436      3.180740
# 13030          3.529999  3.329353           3.010409      3.829490
# 8787           2.808142  3.728095           3.650834      2.767342
#
#        c.updateassist  c.android.vending  c.UCMobile.intl  c.UCMobile.x86  \
# 3350         3.848327           9.894478         3.204495        3.522722
# 10268        6.481330           4.515890         3.660821        7.763940
# 12231        5.125479           6.668629         8.996301        1.660455
# 12431        9.870651           4.983904         3.890928        1.160431
# 2845         4.999987           8.052926         5.592850        5.160869
# ...               ...                ...              ...             ...
# 11190        9.837914           6.589126         7.852166        8.659585
# 10185        4.633412           7.071818         9.941823        5.355845
# 9256         9.773701           4.999265         6.337801        4.671424
# 13030        8.468278           7.460828         9.032830        5.621218
# 8787         5.880364           4.053505         1.341767        4.239929
#
#        c.raider
# 3350   3.566166
# 10268  8.369799
# 12231  5.860677
# 12431  5.888315
# 2845   9.952097
# ...         ...
# 11190  9.577481
# 10185  4.393945
# 9256   4.908253
# 13030  9.228477
# 8787   9.478880
#
# [10145 rows x 30 columns]

# %%
min_max_scaler = MinMaxScaler()
X_train_sq_mn_mx = min_max_scaler.fit_transform(X_train_squared)
X_train_sq_mn_mx
# Out:
# array([[0.66367989, 0.15049933, 0.55785781, ..., 0.32046137, 0.3522722 ,
#         0.3474436 ],
#        [0.64458718, 0.53141438, 0.58941972, ..., 0.36609562, 0.77639404,
#         0.83465562],
#        [0.71106501, 0.56207348, 0.52326775, ..., 0.89966339, 0.16604548,
#         0.58016613],
#        ...,
#        [0.52767763, 0.63806902, 0.83826811, ..., 0.63380351, 0.46714238,
#         0.4835658 ],
#        [0.57468076, 0.23888425, 0.63550699, ..., 0.90331633, 0.56212178,
#         0.92174766],
#        [0.83683429, 0.5201567 , 0.57934625, ..., 0.13418171, 0.42399292,
#         0.94714504]])

# %% [markdown]
# Combination 2: quantile transformation + standardization.

# %%
qt = QuantileTransformer(n_quantiles=10, random_state=0)
X_train_quantiled = qt.fit_transform(X_train)
X_train_quantiled
# Out:
# array([[0.67961081, 0.05425209, 0.42652737, ..., 0.10449921, 0.13610389,
#         0.12612528],
#        [0.64073394, 0.35746971, 0.49820389, ..., 0.13452479, 0.60770982,
#         0.70280769],
#        [0.76556484, 0.41530874, 0.34535708, ..., 0.81410221, 0.03072276,
#         0.34822258],
#        ...,
#        [0.3792867 , 0.58561586, 0.91338382, ..., 0.40398337, 0.23193783,
#         0.24216544],
#        [0.48493133, 0.08901541, 0.59838492, ..., 0.82053126, 0.32588503,
#         0.85195101],
#        [0.90601393, 0.33648156, 0.47556706, ..., 0.01832096, 0.19317099,
#         0.8989915 ]])

# %%
standard_scaler = StandardScaler()
X_train_quan_stand = standard_scaler.fit_transform(X_train_quantiled) 
X_train_quan_stand
# Out:
# array([[ 0.63482626, -1.58132337, -0.26611016, ..., -1.36796368,
#         -1.26018807, -1.29777651],
#        [ 0.49626237, -0.49992223, -0.00921745, ..., -1.26412566,
#          0.37213011,  0.70516841],
#        [ 0.94118125, -0.293644  , -0.5570291 , ...,  1.08606876,
#         -1.6249323 , -0.52638371],
#        ...,
#        [-0.43558075,  0.31374258,  1.47881099, ..., -0.33225236,
#         -0.9284885 , -0.8947435 ],
#        [-0.05904506, -1.45734279,  0.34983706, ...,  1.10830246,
#         -0.6033193 ,  1.223176  ],
#        [ 1.44176609, -0.57477479, -0.09034913, ..., -1.6659954 ,
#         -1.06266795,  1.38655797]])

# %% [markdown]
# Let's see the distributions on each feature to decide

# %% [markdown]
# #### D

# %% [markdown]
# Let's plot distributions after applying two different techniques:

# %%
n = X_train_quan_stand.shape[1]

fig, axes = plt.subplots(nrows=n, ncols=2, figsize=(12, 4 * n))

for i in range(n):
    axes[i, 0].hist(X_train_sq_mn_mx[:, i], bins=10, color='salmon', edgecolor='black')
    axes[i, 0].set_title(f'Feature {i + 1}: MinMax + SquaredRoot')

    axes[i, 1].hist(X_train_quan_stand[:, i], bins=10, color='skyblue', edgecolor='black')
    axes[i, 1].set_title(f'Feature {i + 1} Standard + Quantile')

plt.tight_layout()
plt.show()

# %% [markdown]
# We can see that the MinMax scaling + Squared Root Transformation results in the normal distribution among most of the features, this is why we will stick to the red (go repulicans!) option and choose MinMax scaling + Squared Root Transformation.

# %% [markdown]
# ## 2.2

# %% [markdown]
# ## 2.3

# %% [markdown]
# We implement our pipeline with sklearn

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split

# %%
# input the features that matter:
numerical_features = ['feature1']
categorical_features = ['category1']

# %%
def create_pre_pipeline():
    numerical_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy='mean')),
        ('scaler', StandardScaler())
    ])
    
    categorical_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent')), # 'mean'/'most freq'
        ('encoder', LabelEncoder())
    ])

    preprocessor = ColumnTransformer([
        ('num', numerical_pipeline, numerical_features),
        ('cat', categorical_pipeline, categorical_features)
    ])

    return preprocessor

# %%
preprocessor = create_pre_pipeline()

# %% [markdown]
# We apply to both training and test set:

# %%
X_train_processed = preprocessor.fit_transform(X_train)
X_test_processed = preprocessor.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'feature1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\_indexing.py:361, in _get_column_indices(X, key)
#     360 for col in columns:
# --> 361     col_idx = all_columns.get_loc(col)
#     362     if not isinstance(col_idx, numbers.Integral):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#
# KeyError: 'feature1'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 X_train_processed = preprocessor.fit_transform(X_train)
#       2 X_test_processed = preprocessor.transform(X_test)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\compose\_column_transformer.py:968, in ColumnTransformer.fit_transform(self, X, y, **params)
#     965 self._validate_transformers()
#     966 n_samples = _num_samples(X)
# --> 968 self._validate_column_callables(X)
#     969 self._validate_remainder(X)
#     971 if _routing_enabled():
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\compose\_column_transformer.py:536, in ColumnTransformer._validate_column_callables(self, X)
#     534         columns = columns(X)
#     535     all_columns.append(columns)
# --> 536     transformer_to_input_indices[name] = _get_column_indices(X, columns)
#     538 self._columns = all_columns
#     539 self._transformer_to_input_indices = transformer_to_input_indices
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\_indexing.py:369, in _get_column_indices(X, key)
#     366         column_indices.append(col_idx)
#     368 except KeyError as e:
# --> 369     raise ValueError("A given column is not a column of the dataframe") from e
#     371 return column_indices
#
# ValueError: A given column is not a column of the dataframe

# %% [markdown]
# ### B

# %% [markdown]
# Integrating into a single pipeline, for testing and training:

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
model_pipeline = Pipeline([
    ('preprocessor', create_pre_pipeline()),
    ('classifier', RandomForestClassifier())
])

# %%
# training pipeline
# model_pipeline.fit(X_train, y_train)
